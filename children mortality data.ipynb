# %% [markdown]
# ### Questions
# - What is the country with the least children mortality rate? (Five)
# - What is the country with the most children mortality rate? (Five)?
# - Which Gender gets the most mortalities?
# - What is the country with the best improvement rate (Average) (Five)
# - What is the country with the highest increasein rate of population? (Five)
# - The total mortalities of children in 1967 and 2019 (Comparison)
# - The total average rate in 1967 and 2019

# %% [markdown]
# ## Gather

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ChildMOrtalytRate.csv')
df
# Out:
#        Unnamed: 0      Country  Year  Gender  Child Mortality(1 to 4)  \
# 0               0  Afghanistan  1967  Female                  26012.0
# 1               1  Afghanistan  1968  Female                  26192.0
# 2               2  Afghanistan  1969  Female                  26335.0
# 3               3  Afghanistan  1970  Female                  26562.0
# 4               4  Afghanistan  1971  Female                  26671.0
# ...           ...          ...   ...     ...                      ...
# 30935       30935     Zimbabwe  2015   Total                   9031.0
# 30936       30936     Zimbabwe  2016   Total                   8566.0
# 30937       30937     Zimbabwe  2017   Total                   8318.0
# 30938       30938     Zimbabwe  2018   Total                   7692.0
# 30939       30939     Zimbabwe  2019   Total                   7397.0
#
#        Total Population  Mortality Rate
# 0              5080.813        5.119653
# 1              5202.606        5.034400
# ...

# %% [markdown]
# ## Assess

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30940 entries, 0 to 30939
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               30940 non-null  int64
#  1   Country                  30940 non-null  object
#  2   Year                     30940 non-null  int64
#  3   Gender                   30940 non-null  object
#  4   Child Mortality(1 to 4)  30940 non-null  float64
#  5   Total Population         30064 non-null  float64
#  6   Mortality Rate           30064 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 1.7+ MB

# %%
df.query('Country=="Egypt" and Gender=="Total"')
# Out:
#       Unnamed: 0 Country  Year Gender  Child Mortality(1 to 4)  \
# 8490        8490   Egypt  1960  Total                 123020.0
# 8491        8491   Egypt  1961  Total                 121084.0
# 8492        8492   Egypt  1962  Total                 118908.0
# 8493        8493   Egypt  1963  Total                 116679.0
# 8494        8494   Egypt  1964  Total                 114726.0
# 8495        8495   Egypt  1965  Total                 113166.0
# 8496        8496   Egypt  1966  Total                 112206.0
# 8497        8497   Egypt  1967  Total                 111882.0
# 8498        8498   Egypt  1968  Total                 111910.0
# 8499        8499   Egypt  1969  Total                 112226.0
# 8500        8500   Egypt  1970  Total                 112412.0
# 8501        8501   Egypt  1971  Total                 112286.0
# 8502        8502   Egypt  1972  Total                 111577.0
# 8503        8503   Egypt  1973  Total                 110050.0
# ...

# %%
df.Year.value_counts()
# Out:
# 2015    579
# 1994    579
# 1993    579
# 2008    579
# 1992    579
#        ...
# 1959    242
# 1958    230
# 1957    212
# 1956    188
# 1955    158
# Name: Year, Length: 65, dtype: int64

# %%
df['Year'].value_counts()[:50].sort_values(0)
# Out:
# 1970    377
# 1971    380
# 1972    391
# 1973    403
# 1974    418
# 1975    424
# 1976    439
# 1977    451
# 1978    451
# 1979    460
# 1980    475
# 1981    481
# 1982    484
# 1983    496
# 1984    502
# 1985    514
# 1986    532
# 1987    540
# 1988    543
# 1989    552
# 1995    579
# 1996    579
# 2014    579
# 1998    579
# 2012    579
# 2015    579
# 2011    579
# 1994    579
# 1993    579
# 2008    579
# 1992    579
# 1999    579
# 1991    579
# 2006    579
# 1990    579
# 2005    579
# 2004    579
# 2019    579
# 2003    579
# 2018    579
# 2002    579
# 2017    579
# 2001    579
# 2016    579
# 2000    579
# 2009    579
# 2007    579
# 2010    579
# 2013    579
# 1997    579
# Name: Year, dtype: int64

# %%
df.query('Year>=1989').Year.value_counts()
# Out:
# 2015    579
# 1999    579
# 2016    579
# 2001    579
# 2017    579
# 2002    579
# 2018    579
# 2003    579
# 2019    579
# 2004    579
# 2005    579
# 1990    579
# 2006    579
# 1991    579
# 2007    579
# 1992    579
# 2008    579
# 1993    579
# 2009    579
# 1994    579
# 2010    579
# 1995    579
# 2011    579
# 1996    579
# 2012    579
# 1997    579
# 2013    579
# 1998    579
# 2014    579
# 2000    579
# 1989    552
# Name: Year, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Country'].value_counts().sort_values()[:20]
# Out:
# Somalia                                   66
# Guinea-Bissau                             90
# Timor-Leste                               90
# Palau                                     90
# Nauru                                     90
# Niue                                      90
# Andorra                                   90
# Democratic People's Republic of Korea     90
# Monaco                                    90
# San Marino                                90
# Bosnia and Herzegovina                    93
# Serbia                                    93
# Montenegro                                93
# Suriname                                  96
# Lithuania                                 96
# Azerbaijan                                99
# Equatorial Guinea                         99
# Slovakia                                 102
# North Macedonia                          102
# Micronesia (Federated States of)         102
# Name: Country, dtype: int64

# %% [markdown]
# ### Quality issues
# - The first column should be removed  (DONE)
# - population should be corrected       (DONE)
# - mortality rate is incorrect          (DONE)
# - null values in mortality rates and popularity in some years  (DONE)
# - mortality count and population are floats not int            (DONE)
# - columns names should be changed for simplicity  (DONE)
# - There are missing years (remove what is before 1990)  (DONE)
# - some countries have non-standard names (have sentences in brackets)
#
#
#
# ### Tidiness issues
# - Gender = Total. create a column for total popularity for each year and remove the value "Total" from the gender column (DONE)

# %% [markdown]
# ## Clean

# %% [markdown]
# - The first column should be removed
# #### Define
# - use drop to remove it
# #### Code & Test

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %%
df
# Out:
#            Country  Year  Gender  Child Mortality(1 to 4)  Total Population  \
# 0      Afghanistan  1967  Female                  26012.0          5080.813
# 1      Afghanistan  1968  Female                  26192.0          5202.606
# 2      Afghanistan  1969  Female                  26335.0          5333.936
# 3      Afghanistan  1970  Female                  26562.0          5476.630
# 4      Afghanistan  1971  Female                  26671.0          5630.099
# ...            ...   ...     ...                      ...               ...
# 30935     Zimbabwe  2015   Total                   9031.0         13814.642
# 30936     Zimbabwe  2016   Total                   8566.0         14030.338
# 30937     Zimbabwe  2017   Total                   8318.0         14236.599
# 30938     Zimbabwe  2018   Total                   7692.0         14438.812
# 30939     Zimbabwe  2019   Total                   7397.0         14645.473
#
#        Mortality Rate
# 0            5.119653
# ...

# %% [markdown]
# - column names has spaces and capitalized
# #### Define
# - use string methods to make them in lower case and seperated by underscore
# #### Code & Test

# %%
df.rename(columns ={'Child Mortality(1 to 4)':'child_mortality'}, inplace = True)
df.columns = df.columns.str.lower().str.replace(' ','_')
df.columns
# Out:
# Index(['country', 'year', 'gender', 'child_mortality', 'total_population',
#        'mortality_rate'],
#       dtype='object')

# %% [markdown]
# - There are missing years
# #### Define
# - remove what is before 1990 using masking
# #### Code & Test

# %%
df = df[df['year'] >= 1990]
df
# Out:
#            country  year  gender  child_mortality  total_population  \
# 23     Afghanistan  1990  Female          17160.0          6067.694
# 24     Afghanistan  1991  Female          16712.0          6477.343
# 25     Afghanistan  1992  Female          16474.0          7024.451
# 26     Afghanistan  1993  Female          16394.0          7639.816
# 27     Afghanistan  1994  Female          16455.0          8227.017
# ...            ...   ...     ...              ...               ...
# 30935     Zimbabwe  2015   Total           9031.0         13814.642
# 30936     Zimbabwe  2016   Total           8566.0         14030.338
# 30937     Zimbabwe  2017   Total           8318.0         14236.599
# 30938     Zimbabwe  2018   Total           7692.0         14438.812
# 30939     Zimbabwe  2019   Total           7397.0         14645.473
#
#        mortality_rate
# 23           2.828093
# 24           2.580070
# 25           2.345237
# 26           2.145863
# 27           2.000117
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17370 entries, 23 to 30939
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           17370 non-null  object
#  1   year              17370 non-null  int64
#  2   gender            17370 non-null  object
#  3   child_mortality   17370 non-null  float64
#  4   total_population  16710 non-null  float64
#  5   mortality_rate    16710 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 949.9+ KB

# %% [markdown]
# - population should be corrected
# #### Define
# - multiply the column by 100
# #### Code & Test

# %%
df['total_population'] = df['total_population'] * 1000
# Out:
# C:\Users\Ahmad_Alsebae\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#            country  year  gender  child_mortality  total_population  \
# 23     Afghanistan  1990  Female          17160.0         6067694.0
# 24     Afghanistan  1991  Female          16712.0         6477343.0
# 25     Afghanistan  1992  Female          16474.0         7024451.0
# 26     Afghanistan  1993  Female          16394.0         7639816.0
# 27     Afghanistan  1994  Female          16455.0         8227017.0
# ...            ...   ...     ...              ...               ...
# 30935     Zimbabwe  2015   Total           9031.0        13814642.0
# 30936     Zimbabwe  2016   Total           8566.0        14030338.0
# 30937     Zimbabwe  2017   Total           8318.0        14236599.0
# 30938     Zimbabwe  2018   Total           7692.0        14438812.0
# 30939     Zimbabwe  2019   Total           7397.0        14645473.0
#
#        mortality_rate
# 23           2.828093
# 24           2.580070
# 25           2.345237
# 26           2.145863
# 27           2.000117
# ...

# %% [markdown]
# - null values in mortality rates and popularity in some years
# #### Define
# - remove them (We can't interpolate because no previous or next values)
# #### Code & Test

# %%
df[df['total_population'].isnull()]
# Out:
#        country  year  gender  child_mortality  total_population  \
# 453    Andorra  1990  Female              1.0               NaN
# 454    Andorra  1991  Female              0.0               NaN
# 455    Andorra  1992  Female              0.0               NaN
# 456    Andorra  1993  Female              0.0               NaN
# 457    Andorra  1994  Female              1.0               NaN
# ...        ...   ...     ...              ...               ...
# 28468   Tuvalu  2015    Male              1.0               NaN
# 28469   Tuvalu  2016    Male              2.0               NaN
# 28470   Tuvalu  2017    Male              1.0               NaN
# 28471   Tuvalu  2018    Male              1.0               NaN
# 28472   Tuvalu  2019    Male              1.0               NaN
#
#        mortality_rate
# 453               NaN
# 454               NaN
# 455               NaN
# 456               NaN
# 457               NaN
# ...               ...
# 28468             NaN
# ...

# %%
df.dropna(axis=0,subset=['total_population'], inplace=True)
df
# Out:
# C:\Users\Ahmad_Alsebae\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            country  year  gender  child_mortality  total_population  \
# 23     Afghanistan  1990  Female          17160.0         6067694.0
# 24     Afghanistan  1991  Female          16712.0         6477343.0
# 25     Afghanistan  1992  Female          16474.0         7024451.0
# 26     Afghanistan  1993  Female          16394.0         7639816.0
# 27     Afghanistan  1994  Female          16455.0         8227017.0
# ...            ...   ...     ...              ...               ...
# 30935     Zimbabwe  2015   Total           9031.0        13814642.0
# 30936     Zimbabwe  2016   Total           8566.0        14030338.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16710 entries, 23 to 30939
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           16710 non-null  object
#  1   year              16710 non-null  int64
#  2   gender            16710 non-null  object
#  3   child_mortality   16710 non-null  float64
#  4   total_population  16710 non-null  float64
#  5   mortality_rate    16710 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 913.8+ KB

# %%
df['country'].value_counts().sort_values()[:20]
# Out:
# Nauru                               30
# Cook Islands                        30
# Saint Kitts and Nevis               30
# Palau                               30
# Niue                                30
# Dominica                            30
# Monaco                              30
# San Marino                          30
# Andorra                             30
# Marshall Islands                    30
# Tuvalu                              30
# Somalia                             60
# Sweden                              60
# Lithuania                           60
# Saint Lucia                         90
# Nigeria                             90
# Rwanda                              90
# Turkey                              90
# Saint Vincent and the Grenadines    90
# Libya                               90
# Name: country, dtype: int64

# %%
df[df['country'] == 'Dominica']
# Out:
#        country  year gender  child_mortality  total_population  mortality_rate
# 7965  Dominica  1990  Total              6.0           70422.0        0.085201
# 7966  Dominica  1991  Total              5.0           70377.0        0.071046
# 7967  Dominica  1992  Total              5.0           70546.0        0.070876
# 7968  Dominica  1993  Total              5.0           70818.0        0.070604
# 7969  Dominica  1994  Total              5.0           71044.0        0.070379
# 7970  Dominica  1995  Total              5.0           71105.0        0.070319
# 7971  Dominica  1996  Total              5.0           70933.0        0.070489
# 7972  Dominica  1997  Total              4.0           70592.0        0.056664
# 7973  Dominica  1998  Total              5.0           70183.0        0.071242
# 7974  Dominica  1999  Total              4.0           69828.0        0.057284
# 7975  Dominica  2000  Total              4.0           69650.0        0.057430
# ...

# %%
df[df['country'] == 'Somalia']
# Out:
#        country  year  gender  child_mortality  total_population  \
# 25650  Somalia  1990  Female          11138.0         3594693.0
# 25651  Somalia  1991  Female          11127.0         3621246.0
# 25652  Somalia  1992  Female          11171.0         3633516.0
# 25653  Somalia  1993  Female          11372.0         3644977.0
# 25654  Somalia  1994  Female          11639.0         3674352.0
# 25655  Somalia  1995  Female          11898.0         3734818.0
# 25656  Somalia  1996  Female          12201.0         3831257.0
# 25657  Somalia  1997  Female          12480.0         3958877.0
# 25658  Somalia  1998  Female          12782.0         4109212.0
# 25659  Somalia  1999  Female          13099.0         4269277.0
# 25660  Somalia  2000  Female          13395.0         4429313.0
# 25661  Somalia  2001  Female          13701.0         4587168.0
# 25662  Somalia  2002  Female          14016.0         4745059.0
# 25663  Somalia  2003  Female          14349.0         4902742.0
# ...

# %%
df[df['country'] == 'Lithuania']
# Out:
#          country  year  gender  child_mortality  total_population  \
# 16092  Lithuania  1990  Female             76.0         1947083.0
# 16093  Lithuania  1991  Female             82.0         1948426.0
# 16094  Lithuania  1992  Female             88.0         1944680.0
# 16095  Lithuania  1993  Female             87.0         1937117.0
# 16096  Lithuania  1994  Female             78.0         1927666.0
# 16097  Lithuania  1995  Female             66.0         1917783.0
# 16098  Lithuania  1996  Female             56.0         1907784.0
# 16099  Lithuania  1997  Female             49.0         1897360.0
# 16100  Lithuania  1998  Female             44.0         1886501.0
# 16101  Lithuania  1999  Female             39.0         1875046.0
# 16102  Lithuania  2000  Female             35.0         1862857.0
# 16103  Lithuania  2001  Female             32.0         1850149.0
# 16104  Lithuania  2002  Female             29.0         1837028.0
# ...

# %%
df[df['country'] == 'Sweden']
# Out:
#       country  year  gender  child_mortality  total_population  mortality_rate
# 26507  Sweden  1990  Female             53.0         4335221.0        0.012225
# 26508  Sweden  1991  Female             52.0         4364051.0        0.011916
# 26509  Sweden  1992  Female             50.0         4394992.0        0.011377
# 26510  Sweden  1993  Female             47.0         4425260.0        0.010621
# 26511  Sweden  1994  Female             43.0         4451175.0        0.009660
# 26512  Sweden  1995  Female             40.0         4470258.0        0.008948
# 26513  Sweden  1996  Female             37.0         4481405.0        0.008256
# 26514  Sweden  1997  Female             35.0         4485824.0        0.007802
# 26515  Sweden  1998  Female             33.0         4486170.0        0.007356
# 26516  Sweden  1999  Female             31.0         4486363.0        0.006910
# 26517  Sweden  2000  Female             30.0         4489380.0        0.006682
# ...

# %%
to_delete = df['country'].value_counts().sort_values()[:11].index
for country in to_delete:
    df = df[df['country'] != country]
df.country.value_counts()
# Out:
# Ecuador          90
# Iceland          90
# Eswatini         90
# Armenia          90
# South Africa     90
#                  ..
# United States    90
# India            90
# Sweden           60
# Somalia          60
# Lithuania        60
# Name: country, Length: 183, dtype: int64

# %% [markdown]
# - mortality count and population are floats not int
# #### Define
# - change it using astype
# #### Code & Test

# %%
df['child_mortality'] = df['child_mortality'].astype(int)
df['total_population'] = df['total_population'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16380 entries, 23 to 30939
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           16380 non-null  object
#  1   year              16380 non-null  int64
#  2   gender            16380 non-null  object
#  3   child_mortality   16380 non-null  int32
#  4   total_population  16380 non-null  int32
#  5   mortality_rate    16380 non-null  float64
# dtypes: float64(1), int32(2), int64(1), object(2)
# memory usage: 767.8+ KB

# %% [markdown]
# - Gender = Total. create a column for total population for each year and remove the value "Total" from the gender column
# #### Define
# - make 2 dataframes one for each gender
# - in the male df, insert a female_population, female_mortality and total_population columns and leave them blank
# - create a list for female population and another for mortality
# - assign them to the female population column and female mortality column in the male df
# - the total population column will be the addidtion of male and female
# - note : don't forget to reset index
# #### Code & Test

# %%
df_n = df[df['gender']=='Male']
df_n = df_n.rename(columns = {'total_population':'male_population','child_mortality':'male_mortality'})
df_n
# Out:
#            country  year gender  male_mortality  male_population  \
# 76     Afghanistan  1990   Male           17260          6344616
# 77     Afghanistan  1991   Male           16824          6821673
# 78     Afghanistan  1992   Male           16560          7461092
# 79     Afghanistan  1993   Male           16472          8176785
# 80     Afghanistan  1994   Male           16565          8848711
# ...            ...   ...    ...             ...              ...
# 30874     Zimbabwe  2015   Male            4694          6568778
# 30875     Zimbabwe  2016   Male            4470          6674206
# 30876     Zimbabwe  2017   Male            4342          6777054
# 30877     Zimbabwe  2018   Male            4021          6879119
# 30878     Zimbabwe  2019   Male            3866          6983353
#
#        mortality_rate
# 76           2.720416
# 77           2.466257
# 78           2.219514
# 79           2.014484
# 80           1.872024
# ...               ...
# ...

# %%
df_n.insert(4,'female_mortality' ,value = '')
df_n.insert(5,'total_mortality' ,value = '')
df_n.insert(7,'female_population' ,value = '')
df_n.insert(8,'total_population', value = '')

# %%
df_n
# Out:
#            country  year gender  male_mortality female_mortality  \
# 76     Afghanistan  1990   Male           17260
# 77     Afghanistan  1991   Male           16824
# 78     Afghanistan  1992   Male           16560
# 79     Afghanistan  1993   Male           16472
# 80     Afghanistan  1994   Male           16565
# ...            ...   ...    ...             ...              ...
# 30874     Zimbabwe  2015   Male            4694
# 30875     Zimbabwe  2016   Male            4470
# 30876     Zimbabwe  2017   Male            4342
# 30877     Zimbabwe  2018   Male            4021
# 30878     Zimbabwe  2019   Male            3866
#
#       total_mortality  male_population female_population total_population  \
# 76                             6344616
# 77                             6821673
# 78                             7461092
# 79                             8176785
# 80                             8848711
# ...               ...              ...               ...              ...
# ...

# %%
df_female = df[df['gender']=='Female']
df_female = df_female.rename(columns = {'total_population':'female_population','child_mortality':'female_mortality'})
df_female
# Out:
#            country  year  gender  female_mortality  female_population  \
# 23     Afghanistan  1990  Female             17160            6067694
# 24     Afghanistan  1991  Female             16712            6477343
# 25     Afghanistan  1992  Female             16474            7024451
# 26     Afghanistan  1993  Female             16394            7639816
# 27     Afghanistan  1994  Female             16455            8227017
# ...            ...   ...     ...               ...                ...
# 30813     Zimbabwe  2015  Female              4337            7245864
# 30814     Zimbabwe  2016  Female              4096            7356132
# 30815     Zimbabwe  2017  Female              3976            7459545
# 30816     Zimbabwe  2018  Female              3671            7559693
# 30817     Zimbabwe  2019  Female              3531            7662120
#
#        mortality_rate
# 23           2.828093
# 24           2.580070
# 25           2.345237
# 26           2.145863
# ...

# %%
df_female_pop = list(df_female['female_population'].values)
df_female_pop
# Out:
# [6067694,
#  6477343,
#  7024451,
#  7639816,
#  8227017,
#  8718035,
#  9082951,
#  9344885,
#  9553498,
#  9784258,
#  10090449,
#  10489238,
#  10958668,
#  11466237,
#  11962963,
#  12414590,
#  12809162,
#  13161572,
#  13496556,
#  13850751,
#  14249755,
#  14702050,
#  15196503,
#  15715313,
#  16232001,
#  16727436,
#  17196034,
#  17644126,
#  18078879,
#  18512030,
#  1603312,
#  1611474,
#  1609731,
#  1601043,
#  1589832,
#  1579417,
#  1570487,
#  1562385,
#  1555510,
#  1549960,
#  1545740,
#  1543523,
#  1543247,
#  1543176,
#  1540927,
#  1534835,
#  1524300,
#  1510100,
#  1493764,
#  1477486,
#  1462961,
#  1450542,
#  1439880,
#  1431118,
#  1424212,
#  1419068,
#  1415879,
#  1414581,
#  1414359,
#  1414128,
#  12722507,
#  13035546,
#  13343646,
#  13642618,
#  13927251,
#  14194153,
#  14442437,
#  14674195,
#  14892933,
#  15103751,
#  15311139,
#  15516424,
#  15721105,
#  15930173,
#  16149500,
#  16383693,
#  16634748,
#  16903082,
#  17189426,
#  17493858,
# ...

# %%
df_female_mort = list(df_female['female_mortality'].values)
df_female_mort
# Out:
# [17160,
#  16712,
#  16474,
#  16394,
#  16455,
#  16637,
#  16874,
#  17142,
#  17360,
#  17524,
#  17589,
#  17524,
#  17333,
#  17038,
#  16680,
#  16206,
#  15701,
#  15136,
#  14514,
#  13849,
#  13190,
#  12523,
#  11796,
#  11108,
#  10436,
#  9795,
#  9220,
#  8675,
#  8218,
#  7803,
#  237,
#  223,
#  209,
#  197,
#  183,
#  168,
#  154,
#  140,
#  126,
#  113,
#  101,
#  87,
#  78,
#  69,
#  59,
#  52,
#  45,
#  40,
#  35,
#  32,
#  28,
#  26,
#  23,
#  21,
#  21,
#  20,
#  20,
#  19,
#  19,
#  19,
#  3013,
#  2903,
#  2776,
#  2659,
#  2533,
#  2390,
#  2231,
#  2105,
#  1992,
#  1895,
#  1803,
#  1715,
#  1617,
#  1521,
#  1452,
#  1405,
#  1379,
#  1373,
#  1380,
#  1404,
#  1432,
#  1470,
#  1509,
#  1548,
#  1581,
#  1609,
#  1623,
#  1629,
#  1623,
#  1602,
#  23992,
#  24796,
#  25584,
#  26391,
#  27120,
#  27779,
#  28322,
#  28666,
#  28926,
#  28997,
#  28955,
#  28728,
#  28431,
#  27926,
#  27179,
#  26316,
#  25378,
#  24322,
#  23213,
#  22067,
#  21023,
# ...

# %%
df_n['female_population'] = df_female_pop
df_n
# Out:
#            country  year gender  male_mortality female_mortality  \
# 76     Afghanistan  1990   Male           17260
# 77     Afghanistan  1991   Male           16824
# 78     Afghanistan  1992   Male           16560
# 79     Afghanistan  1993   Male           16472
# 80     Afghanistan  1994   Male           16565
# ...            ...   ...    ...             ...              ...
# 30874     Zimbabwe  2015   Male            4694
# 30875     Zimbabwe  2016   Male            4470
# 30876     Zimbabwe  2017   Male            4342
# 30877     Zimbabwe  2018   Male            4021
# 30878     Zimbabwe  2019   Male            3866
#
#       total_mortality  male_population  female_population total_population  \
# 76                             6344616            6067694
# 77                             6821673            6477343
# 78                             7461092            7024451
# 79                             8176785            7639816
# ...

# %%
df_n['female_mortality'] = df_female_mort
df_n
# Out:
#            country  year gender  male_mortality  female_mortality  \
# 76     Afghanistan  1990   Male           17260             17160
# 77     Afghanistan  1991   Male           16824             16712
# 78     Afghanistan  1992   Male           16560             16474
# 79     Afghanistan  1993   Male           16472             16394
# 80     Afghanistan  1994   Male           16565             16455
# ...            ...   ...    ...             ...               ...
# 30874     Zimbabwe  2015   Male            4694              4337
# 30875     Zimbabwe  2016   Male            4470              4096
# 30876     Zimbabwe  2017   Male            4342              3976
# 30877     Zimbabwe  2018   Male            4021              3671
# 30878     Zimbabwe  2019   Male            3866              3531
#
#       total_mortality  male_population  female_population total_population  \
# 76                             6344616            6067694
# ...

# %%
df_n['total_population'] = df_n['female_population'] + df_n['male_population']
df_n['total_mortality'] = df_n['male_mortality'] + df_n['female_mortality']
df_n
# Out:
#            country  year gender  male_mortality  female_mortality  \
# 76     Afghanistan  1990   Male           17260             17160
# 77     Afghanistan  1991   Male           16824             16712
# 78     Afghanistan  1992   Male           16560             16474
# 79     Afghanistan  1993   Male           16472             16394
# 80     Afghanistan  1994   Male           16565             16455
# ...            ...   ...    ...             ...               ...
# 30874     Zimbabwe  2015   Male            4694              4337
# 30875     Zimbabwe  2016   Male            4470              4096
# 30876     Zimbabwe  2017   Male            4342              3976
# 30877     Zimbabwe  2018   Male            4021              3671
# 30878     Zimbabwe  2019   Male            3866              3531
#
#        total_mortality  male_population  female_population  total_population  \
# 76               34420          6344616            6067694          12412310
# ...

# %%
df_n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5490 entries, 76 to 30878
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            5490 non-null   object
#  1   year               5490 non-null   int64
#  2   gender             5490 non-null   object
#  3   male_mortality     5490 non-null   int32
#  4   female_mortality   5490 non-null   int64
#  5   total_mortality    5490 non-null   int64
#  6   male_population    5490 non-null   int32
#  7   female_population  5490 non-null   int64
#  8   total_population   5490 non-null   int64
#  9   mortality_rate     5490 non-null   float64
# dtypes: float64(1), int32(2), int64(5), object(2)
# memory usage: 428.9+ KB

# %%
df_n.drop(['gender','mortality_rate'] , axis = 1, inplace = True)
df_n
# Out:
#            country  year  male_mortality  female_mortality  total_mortality  \
# 76     Afghanistan  1990           17260             17160            34420
# 77     Afghanistan  1991           16824             16712            33536
# 78     Afghanistan  1992           16560             16474            33034
# 79     Afghanistan  1993           16472             16394            32866
# 80     Afghanistan  1994           16565             16455            33020
# ...            ...   ...             ...               ...              ...
# 30874     Zimbabwe  2015            4694              4337             9031
# 30875     Zimbabwe  2016            4470              4096             8566
# 30876     Zimbabwe  2017            4342              3976             8318
# 30877     Zimbabwe  2018            4021              3671             7692
# 30878     Zimbabwe  2019            3866              3531             7397
#
# ...

# %% [markdown]
# - mortality rate is incorrect
# #### Define
# - create a column for each type (male/male, female/females, male/total, female/total, total)
# - do the math for each
# #### Code & Test

# %%
df_n.insert(8,'male/males_mortality_rate', value = '')
df_n.insert(9,'female/females_mortality_rate' ,value = '')
df_n.insert(10,'male/total_mortality_rate', value = '')
df_n.insert(11,'female/total_mortality_rate', value = '')
df_n.insert(12,'total_mortality_rate', value = '')
df_n
# Out:
#            country  year  male_mortality  female_mortality  total_mortality  \
# 76     Afghanistan  1990           17260             17160            34420
# 77     Afghanistan  1991           16824             16712            33536
# 78     Afghanistan  1992           16560             16474            33034
# 79     Afghanistan  1993           16472             16394            32866
# 80     Afghanistan  1994           16565             16455            33020
# ...            ...   ...             ...               ...              ...
# 30874     Zimbabwe  2015            4694              4337             9031
# 30875     Zimbabwe  2016            4470              4096             8566
# 30876     Zimbabwe  2017            4342              3976             8318
# 30877     Zimbabwe  2018            4021              3671             7692
# 30878     Zimbabwe  2019            3866              3531             7397
#
# ...

# %%
df_n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5490 entries, 76 to 30878
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   country                        5490 non-null   object
#  1   year                           5490 non-null   int64
#  2   male_mortality                 5490 non-null   int32
#  3   female_mortality               5490 non-null   int64
#  4   total_mortality                5490 non-null   int64
#  5   male_population                5490 non-null   int32
#  6   female_population              5490 non-null   int64
#  7   total_population               5490 non-null   int64
#  8   male/males_mortality_rate      5490 non-null   object
#  9   female/females_mortality_rate  5490 non-null   object
#  10  male/total_mortality_rate      5490 non-null   object
#  11  female/total_mortality_rate    5490 non-null   object
# ...

# %%
df_n['male/males_mortality_rate'] = df_n['male_mortality'] / df_n['male_population']

# %%
df_n['female/females_mortality_rate'] = df_n['female_mortality'] / df_n['female_population']

# %%
df_n['male/total_mortality_rate'] = df_n['male_mortality'] / df_n['total_population']

# %%
df_n['female/total_mortality_rate'] = df_n['female_mortality'] / df_n['total_population']

# %%
df_n['total_mortality_rate'] = df_n['total_mortality'] / df_n['total_population']

# %%
df_n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5490 entries, 76 to 30878
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   country                        5490 non-null   object
#  1   year                           5490 non-null   int64
#  2   male_mortality                 5490 non-null   int32
#  3   female_mortality               5490 non-null   int64
#  4   total_mortality                5490 non-null   int64
#  5   male_population                5490 non-null   int32
#  6   female_population              5490 non-null   int64
#  7   total_population               5490 non-null   int64
#  8   male/males_mortality_rate      5490 non-null   float64
#  9   female/females_mortality_rate  5490 non-null   float64
#  10  male/total_mortality_rate      5490 non-null   float64
#  11  female/total_mortality_rate    5490 non-null   float64
# ...

# %%
df_n
# Out:
#            country  year  male_mortality  female_mortality  total_mortality  \
# 76     Afghanistan  1990           17260             17160            34420
# 77     Afghanistan  1991           16824             16712            33536
# 78     Afghanistan  1992           16560             16474            33034
# 79     Afghanistan  1993           16472             16394            32866
# 80     Afghanistan  1994           16565             16455            33020
# ...            ...   ...             ...               ...              ...
# 30874     Zimbabwe  2015            4694              4337             9031
# 30875     Zimbabwe  2016            4470              4096             8566
# 30876     Zimbabwe  2017            4342              3976             8318
# 30877     Zimbabwe  2018            4021              3671             7692
# 30878     Zimbabwe  2019            3866              3531             7397
#
# ...

# %% [markdown]
# - some countries have non-standard names (have sentences in brackets)
# #### Define
# - use regex to replace them with nothing
# #### Code & Test

# %%
df_n['country'] = df_n['country'].str.replace('\(.*?\)','')
list(df_n['country'].value_counts().index)
# Out:
# ['Ecuador',
#  'Czechia',
#  'Cyprus',
#  'Lebanon',
#  'Niger',
#  'Botswana',
#  'Bahamas',
#  'South Sudan',
#  'Antigua and Barbuda',
#  'Angola',
#  'Cameroon',
#  'Congo',
#  'Israel',
#  'United States',
#  'Dominican Republic',
#  'Colombia',
#  'Italy',
#  'India',
#  'Oman',
#  "Lao People's Democratic Republic",
#  'Timor-Leste',
#  'Tajikistan',
#  'Georgia',
#  'Trinidad and Tobago',
#  'Canada',
#  'Venezuela ',
#  'Samoa',
#  'Mongolia',
#  'Latvia',
#  'Zambia',
#  'Ethiopia',
#  'Albania',
#  'Uganda',
#  'Estonia',
#  'Luxembourg',
#  'Brazil',
#  'Thailand',
#  'Bangladesh',
#  'Guyana',
#  'Netherlands',
#  'Iran ',
#  'Jamaica',
#  'Poland',
#  'Algeria',
#  'Tonga',
#  'Madagascar',
#  'Malaysia',
#  'Jordan',
#  'Kiribati',
#  'Gambia',
#  'Russian Federation',
#  'Barbados',
#  "Côte d'Ivoire",
#  'Grenada',
#  'Viet Nam',
#  'Argentina',
#  'Mauritius',
#  'Honduras',
#  'Myanmar',
#  'Somalia',
#  'Democratic Republic of the Congo',
#  'Eritrea',
# ...

# %%
df_n.to_csv('children_mortalily_cleaned.csv', index = False)

# %%
len(df_n.country.value_counts().index)
# Out:
# 183
